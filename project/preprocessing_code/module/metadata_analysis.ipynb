# %%
import pathlib 
import os
import numpy as np
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots

# %%
folder_to_metadata = "/net/data.isilon/ag-cherrmann/nschmidt/project/parse_xml_for_VAE/metadata_20250110"

# %%
def combine_dfs(paths: list):
    # Combines any number of csv files to a single pandas DataFrame, keeping only shared column indices. 
    for i in range(1,len(paths)):
        if i == 1: 
            joined_df = pd.read_csv(paths[i-1], header=[0], index_col=0)
            next_df = pd.read_csv(paths[i], header=[0], index_col=0)
            joined_df = pd.concat([joined_df, next_df], join="inner")  # Parameter "inner" keeps only the shared column indices.
        else:
            next_df = pd.read_csv(paths[i], header=[0], index_col=0)
            joined_df = pd.concat([joined_df, next_df], join="inner")
    return joined_df

# %%
path_to_metadata = [f"{folder_to_metadata}/full_data_train_valid_test.csv",
                    f"{folder_to_metadata}/meta_data_NSS_all_variables.csv",
                    f"{folder_to_metadata}/meta_data_whiteCAT_all_variables.csv"]

# %%
metadata_df = combine_dfs(paths=path_to_metadata)
metadata_df
# Out:
#                               Filename   Dataset Diagnosis        Age     Sex  \
# Unnamed: 0
# 0                   IXI426-IOP-1011-T1       IXI        HC  41.200000  Female
# 1                   IXI571-IOP-1154-T1       IXI        HC  56.600000  Female
# 2                  IXI170-Guys-0843-T1       IXI        HC  50.200000  Female
# 3                  IXI054-Guys-0707-T1       IXI        HC  60.800000  Female
# 4                  IXI196-Guys-0805-T1       IXI        HC  47.800000  Female
# ...                                ...       ...       ...        ...     ...
# 157         sub-whiteCAT130_ses-01_T1w  whiteCAT      SCHZ  27.167693  Female
# 158         sub-whiteCAT132_ses-01_T1w  whiteCAT       CTT  18.817248  Female
# 159         sub-whiteCAT133_ses-01_T1w  whiteCAT      SCHZ  59.737166  Female
# 160         sub-whiteCAT134_ses-01_T1w  whiteCAT       CTT  22.729637  Female
# 161         sub-whiteCAT135_ses-01_T1w  whiteCAT      SCHZ  61.604381  Female
#
#            Usage_original  Sex_int
# Unnamed: 0
# 0                training        0
# 1                training        0
# 2                training        0
# 3                training        0
# 4                training        0
# ...                   ...      ...
# 157               testing        0
# 158               testing        0
# 159               testing        0
# 160               testing        0
# 161               testing        0
#
# [3171 rows x 7 columns]

# %%
total_fig = make_subplots(rows=4, cols=1, subplot_titles=["HC", "MDD", "SCHZ", "CTT"])
total_fig.update_layout(height=800)

conditions = ["HC", "MDD", "SCHZ", "CTT"]

for idx, cond in enumerate(conditions):
    fig = px.histogram(data_frame=metadata_df[(metadata_df["Diagnosis"] == cond) & ~(metadata_df["Dataset"]=="NU")], 
                       x="Age", 
                       title=cond,
                       )
    total_fig.add_trace(fig.data[0], row=idx+1, col=1)
    total_fig.update_yaxes(range=[0.0, 300.0], row=idx+1, col=1)
    total_fig.update_xaxes(range=[0.0, 90.0], row=idx+1, col=1)

total_fig.show()
# Out:
# <div>                            <div id="ddc313e8-d607-4c56-97ab-86540ccc8573" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddc313e8-d607-4c56-97ab-86540ccc8573")) {                    Plotly.newPlot(                        "ddc313e8-d607-4c56-97ab-86540ccc8573",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":
.0,21.0,30.0,60.0,58.0,32.0,25.0,24.0,68.0,71.0,44.0,61.0,34.0,23.0,32.0,19.0,52.0,43.0,49.0,25.0,53.0,61.0,23.0,22.0,43.0,21.0,49.0,48.0,42.0,55.0,58.0,40.0,49.0,23.0,22.0,31.0,57.0,38.0,50.0,25.0,42.0,20.0,44.0,45.0,69.0,29.0,20.0,71.0,22.0,33.0,49.0,60.0,72.0,47.0,49.0,45.0,55.0,44.0,47.0,28.0,32.0,66.0,52.0,31.0,22.0,23.0,56.0,26.0,42.0,43.0,22.0,21.0,31.0,48.0,23.0,20.0,45.0,72.0,54.0,46.0,52.0,20.0,27.0,67.0,20.0,44.0,23.0,39.0,45.0,60.0,22.0,22.0,37.0,24.0,20.0,26.0,36.0,34.0,47.0,36.0,42.0,55.0,32.0,19.0,45.0,27.0,71.0,62.0,27.0,31.0,72.0,22.0,51.0,33.0,38.0,40.0,42.0,32.0,46.0,66.0,45.0,24.0,58.0,34.0,50.0,55.0,30.0,54.0,69.0,34.0,34.0,42.0,52.0,25.0,35.0,64.0,41.0,38.0,70.0,32.0,41.0,25.0,38.0,68.0,50.0,42.0,43.0,21.0,61.0,72.0,39.0,34.0,46.0,43.0,21.0,27.0,24.0,56.0,32.0,48.0,29.0,38.0,18.0,44.0,21.0,65.0,21.0,40.0,36.0,78.0,46.0,48.0,43.0,23.0,44.0,36.0,20.0,20.0,37.0,26.0,36.0,28.0,48.0,19.0,44.0,45.0,54.0,45.0,64.0,37.0,47.0,28.0,69.0,23.0,72.0,35.0,55.0,40.0,20.0,24.0,59.0,54.0,20.0,50.0,24.0,30.0,24.0,56.0,38.0,55.0,30.0,25.0,65.0,27.0, ...

# %%
# Validation that only the NU dataset doesn't contain age information. 
metadata_df[(metadata_df["Age"]==0) & ~(metadata_df["Dataset"]=="NU")]
# Out:
# Empty DataFrame
# Columns: [Filename, Dataset, Diagnosis, Age, Sex, Usage_original, Sex_int]
# Index: []

# %%
total_fig_sexes = make_subplots(rows=1, cols=4, subplot_titles=["HC", "MDD", "SCHZ", "CTT"])
total_fig_sexes.update_layout(width=800)

conditions = ["HC", "MDD", "SCHZ", "CTT"]

for idx, cond in enumerate(conditions):
    df_cond = metadata_df[metadata_df["Diagnosis"] == cond]

    sex_counts = df_cond.groupby("Sex").size().reset_index(name='Count')

    fig = px.bar(data_frame=sex_counts, 
                       x="Sex",
                       y="Count", 
                       title=cond,
                       )
                    
    total_fig_sexes.add_trace(fig.data[0], row=1, col=idx+1)
    # total_fig_sexes.update_yaxes(range=[0.0, 300.0], row=1, col=idx+1)
    # total_fig_sexes.update_xaxes(range=[0.0, 90.0], row=1, col=idx+1)

total_fig_sexes.show()
# Out:
# <div>                            <div id="1cdda821-bc91-480e-927b-84a5bc6c851b" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cdda821-bc91-480e-927b-84a5bc6c851b")) {                    Plotly.newPlot(                        "1cdda821-bc91-480e-927b-84a5bc6c851b",                        [{"alignmentgroup":"True","hovertemplate":"Sex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male"],"xaxis":"x","y":[790,877],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male"],"xaxis":"x2","y":[153,148],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male"],"xaxis":"x3","y":[408,645],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male"],"xaxis":"x4","y":[58,92],"yaxis":"y4","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surfac ...

# %%
shuffle_df = metadata_df.copy()
shuffle_df = shuffle_df.sample(frac=1)
corr_fig = px.scatter(x=shuffle_df["Age"], color=shuffle_df["Diagnosis"])
corr_fig.show()
# Out:
# <div>                            <div id="4d539b89-c33e-4062-bb67-9aba8a202c70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d539b89-c33e-4062-bb67-9aba8a202c70")) {                    Plotly.newPlot(                        "4d539b89-c33e-4062-bb67-9aba8a202c70",                        [{"hovertemplate":"color=HC\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HC","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"HC","showlegend":true,"x":[22.0,75.7,0.0,75.9,32.0,0.0,0.0,31.0,0.0,71.8,53.0,44.0,50.0,26.0,59.1,31.0,57.6,76.7,43.0,58.5,55.0,67.0,55.0,18.0,56.3,0.0,52.0,0.0,23.0,52.0,79.8,42.7,24.0,0.0,0.0,0.0,0.0,40.0,21.0,25.0,39.0,25.0,56.0,26.0,49.0,21.0,58.0,54.5,44.0,0.0,23.0,72.0,23.0,0.0,57.2,59.3,53.0,66.0,52.0,0.0,31.0,51.6,42.4,78.8,18.0,72.4,0.0,23.0,53.2,19.0,21.0,44.0,53.0,37.0,36.0,34.0,41.9,78.3,0.0,47.0,62.9,0.0,57.0,22.0,20.0,0.0,45.0,48.0,42.0,38.0,25.0,0.0,24.0,30.0,20.0,25.0,31.0,69.6,71.4,60.0,30.0,18.0,54.0,55.0,23.0,71.0,21.0,64.0,37.0,35.0,0.0,65.0,25.0,0.0,56.0,0.0,24.0,31.0,0.0,0.0,29.0,0.0,45.0,23.0,39.0,34.0,26.0,48.0,54.0,19.0,79.6,61.0,20.0,21.0,0.0,0.0,20.0,27.0,0.0,22.0,39.0,43.0,33.0,40.0,25.0,22.0,53.0,62.8,58.3,23.0,77.8,0.0,30.0,36.0,24.0,56.7,42.0,0.0,43.8,0.0,23.0,43.0,0.0,49.0,24.0,34.0,21.0,52.1,59.7,68.0,20.0,0.0,45.0,63.0,80.0,65.5,43.0,78.0,46.0,0.0,22.0,0.0,47.0,24.0,0.0,0.0,21.0,42.0,0.0,24.0,49.0,78.0,77.8,43.0,75.5,45.9,32.0,19.0,36.0,0.0,0.0,67.0,78.9,59.1,37.0,66.8,39.0,79.7,22.0,65.8,0.0,0.0,44.4,50.8,0.0,60.0,54.0,21.0,22.0,0.0,20.0,40.0,56.0,42.0,0.0,19.0,19.0,72.0,42.0,33.0,33.0,0.0,20.0,24.0,30.0,71.0,51.4,54.8,19.0,0.0,0.0,0.0,39.0,23.0,47.2,39.6,37.0,71.0,59.0,45.0,59.6,59.0,24.0,0.0,20.0,0.0,76.7,24.0,29.0,22.0,42.5,36.0,66.9,46.8,42.0,45.8,21.0,77.7,64.0,26.0,48.0,21.0,65.7,43.6,25.0,38.0,52.1,0.0,30.0,19.0,68.3,58.0,47.0,0.0,42.0,65.0,76.8,42.0,46.0,0.0,27.0,34.0,23.0,25.0,31.0,20.0,24.0,50.0,37.0,36.0,40.0,78.3,36.0,43.6,0.0,43.5,22.0,0.0,0.0,73.1,40.0,0.0,44.0,76.1,43.8,0.0,42.0,18.0,23.0,68.0,0.0,23.0,22.0,52.5,65.1,52.0,25.0,32.0,59.0,0.0,78.3,0.0,33.0,56.0,72.0,48.0,46.1,48.0,77.9,66.2,0.0,20.0,67.6,47.1,66.0,31.0,41.2,21.0,44.0,72.5,43.5,32.0,22.0,0.0,63.0,0.0,0.0,22.0,49.1,38.0,31.0,63.9,41.0,51.4,40.0,31.0,50.8,0.0,34.0,77.4,21.0,35.0,43.0,78.9,75.0,64.3,0.0,38.7,32.0,0.0,0.0,45.2,0.0,74.0,0.0,31.0,53.9,46.6,79.7,30.0,63.1,43.0,0.0,26.0,23.0,41.0,36.0,23.0,22.0,65.4,46.0,26.0,59.4,44.0,64.0,35.0,27.0,38.0,0.0,66.0,31.0,42.0,46.0,27.0,36.0,53.7,60.0,0.0,73.5,50.0,0.0,76.7,53.1,49.7,21.0,52.1,43.0,29.0,58.0,29.0,0.0,0.0,48.0,0.0,68.4,42.0,48.0,0.0,0.0,55.6,49.0,55.0,42.2,65.0,76.6,0.0,24.0,23.0,32.0,48.0,0.0,0.0,0.0,39.0,0.0,46.7,59.0,78.1,69.0,65.0,56.7,51.0,61.0,23.0,35.0,48.0,46.7,47.0,19.0,41.0,26.0,54.0,0.0,51.6,31.0,21.0,60.7,22.0,24.0,29.0,0.0,80.0,20.0,21.0,45.0,68.2,29.0,45.0,30.0,77.6,23.0,46.0,42.0,48.0,0.0,38.0,77.3,74.2,70.0,0.0,0.0,27.0,41.9,48.0,32.0,59.1,0.0,27.0,20.0,31.0,48.4,41.3,48.0,45.9,21.0,35.0,20.0,33.0,23.0,19.0,49.9,0.0,30.0,22.0,38.0,0.0,0.0,26.0,59.4,18.0,32.0,42.0,30.0,68.0,64.1,55.6,31.0,24.0,0.0,0.0,78.9,27.0,67.0,20.0,55.0,44.7,0.0,43.0,41.1,49.0,0.0,0.0,62.2,64.5,0.0,56.9,55.4,27.0,23.0,79.9,25.0,26.0,21.0,49.0,36.0,0.0,0.0,48.1,0.0,20.0,38.0,0.0,73.4,31.0,64.2,79.0,57.8,32.0,21.0,0.0,48.3,32.0,52.0,23.0,49.0,52.0,0.0,0.0,68.0,43.0,69.0,67.3,19.0,44.0,55.0,64.7,22.0,52.0,79.9,72.0,24.0,31.0,48.0,23.0,23.0,19.0,31.0,0.0,43.0,63.9,21.0,33.0,43.0,22.0,31.0,67.0,0.0,24.0,56.6,69.0,60.1,54.0,24.0,42.0,51.4,62.0,39.0,79.4,52.0,0.0,0.0,50.6,43.0,37.0,25.0,22.0,27.0,39.0,48.0,0.0,60.6,40.6,55.0,22.0,47.0,49.4,27.0,77.9,75.5,0.0,25.0,23.0,20.0,70.0,44.0,0.0,41.0,78.3,72.9,40.4,38.0,32.0,64.0,53.9,22.0,61.0,61.0,47.5,52.0,64.7,59.3,51 ...

# %%
filter_df = metadata_df.loc[metadata_df["Dataset"] != "NU"]
boxplot = px.box(x=filter_df["Diagnosis"], y=filter_df["Age"], color=filter_df["Diagnosis"], width=800,range_y=[0, 90])
boxplot.show()
# Out:
# <div>                            <div id="71d88b7e-9917-406b-bb01-bcd2bda0deb9" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71d88b7e-9917-406b-bb01-bcd2bda0deb9")) {                    Plotly.newPlot(                        "71d88b7e-9917-406b-bb01-bcd2bda0deb9",                        [{"alignmentgroup":"True","hovertemplate":"color=HC\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HC","marker":{"color":"#636efa"},"name":"HC","notched":false,"offsetgroup":"HC","orientation":"v","showlegend":true,"x":["HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC","HC", ...
